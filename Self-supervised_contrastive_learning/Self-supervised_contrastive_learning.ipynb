# %%
# Data visualize를 위한 imports
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
# GPU 한 개만 할당을 위함
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]="0, 1, 2, 3"

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision import transforms
from configparser import Interpolation
from saveLoad import save, load
from sklearn.metrics import confusion_matrix
import seaborn as sn
from util import TwoCropTransform, AverageMeter
from util import adjust_learning_rate, warmup_learning_rate, accuracy
from util import set_optimizer, save_model
from resnet_big import SupConResNet
from losses import SupConLoss
from torchvision.transforms.functional import to_pil_image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())

pd.set_option('display.max.colwidth', 30)

# 경로 설정하기
original_data_path = '/disk1/colonoscopy_dataset/cropped/' # ADC / HGD / LGD / NOR
base_dir = '/home/sundongk/Self-supervised_contrastive_learning'
data_dir = original_data_path
ckpt_dir = os.path.join(base_dir, "checkpoint")
root_dir = '/home/sundongk/dataset/'
train_path = os.path.join(root_dir, 'train')
valid_path = os.path.join(root_dir, 'valid')
test_path = os.path.join(root_dir, 'test')
checkpoint_path_1 = os.path.join(base_dir, 'chk_loss')
checkpoint_path_2 = os.path.join(base_dir, 'chk_acc')
q_encoder_path = os.path.join(base_dir, 'q_encoder_chk')
k_encoder_path = os.path.join(base_dir, 'k_encoder_chk')
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 4

# %% [markdown]
# # Datasets for training model

# %%
batch_size = 128; test_batch_size = 1

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((256,256)),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.590, 0.351, 0.259],
                                 std=[0.241, 0.199, 0.163])
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((256,256)),
        transforms.RandomResizedCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.590, 0.351, 0.259],
                                 std=[0.241, 0.199, 0.163])
    ]),
    'test':
    transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.590, 0.351, 0.259],
                                 std=[0.241, 0.199, 0.163])
    ])
}

class Split:
    def __init__(self, base_transform):
        self.base_transform = base_transform
    
    def __call__(self, x):
        q = self.base_transform(x)
        k = self.base_transform(x)
        return [q, k]

image_datasets = {
    'train': ImageFolder(root=train_path, transform=Split((data_transforms['train'])), target_transform=None),
    'validation': ImageFolder(root=valid_path, transform=Split(data_transforms['validation']), target_transform=None),
    'test': ImageFolder(root=test_path, transform=Split(data_transforms['test']), target_transform=None),
}

dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=batch_size, shuffle=True, num_workers=8),
    'validation': DataLoader(image_datasets['validation'], batch_size=batch_size, shuffle=False, num_workers=8),
    'test': DataLoader(image_datasets['test'], batch_size=test_batch_size, shuffle=False, num_workers=8)
}

# %%
img, label = image_datasets['train'][0]

query, key = img[0], img[1]

print('img size: ', query.shape)

# denormalization query
og = query.cpu().squeeze(0).permute(1,2,0).numpy()
og[:,:,0] = ((og[:,:,0]) * 0.241) + 0.590
og[:,:,1] = ((og[:,:,1]) * 0.199) + 0.351
og[:,:,2] = ((og[:,:,2]) * 0.163) + 0.259
# denormalization key
key = key.cpu().squeeze(0).permute(1,2,0).numpy()
key[:,:,0] = ((key[:,:,0]) * 0.241) + 0.590
key[:,:,1] = ((key[:,:,1]) * 0.199) + 0.351
key[:,:,2] = ((key[:,:,2]) * 0.163) + 0.259

# display query and key
plt.figure(figsize=(10,10)); plt.subplot(1,2,1)
plt.imshow(og)
plt.title('Query'); plt.axis('off'); plt.subplot(1,2,2)
plt.imshow(key)
plt.title('Key'); plt.axis('off')
# Out:
# img size:  torch.Size([3, 224, 224])
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# # Resnet18
#
# - Self-supervised contrastive learning

# %%
from torchvision import models
import copy

q_encoder = models.resnet18(pretrained=False)

classifier = nn.Sequential(
                nn.Linear(q_encoder.fc.in_features, 100),
                nn.ReLU(inplace=True), # input 수정, 메모리 효율 up
                nn.Linear(100, 50),
                nn.ReLU(inplace=True),
                nn.Linear(50, 25)).to(device)
                
q_encoder.fc = classifier
k_encoder = copy.deepcopy(q_encoder)

if torch.cuda.is_available():
    if torch.cuda.device_count() > 1:
        q_encoder = torch.nn.DataParallel(q_encoder)

    q_encoder = q_encoder.cuda()
    k_encoder = k_encoder.cuda()
# Out:
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
from torchsummary import summary
summary(q_encoder, (3, 256, 256), device = device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           9,408
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#          MaxPool2d-4           [-1, 64, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               ReLU-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#        BasicBlock-11           [-1, 64, 64, 64]               0
#            Conv2d-12           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-13           [-1, 64, 64, 64]             128
#              ReLU-14           [-1, 64, 64, 64]               0
#            Conv2d-15           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-16           [-1, 64, 64, 64]             128
#              ReLU-17           [-1, 64, 64, 64]               0
#        BasicBlock-18           [-1, 64, 64, 64]               0
#            Conv2d-19          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-20          [-1, 128, 32, 32]             256
#              ReLU-21          [-1, 128, 32, 32]               0
#            Conv2d-22          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-23          [-1, 128, 32, 32]             256
#            Conv2d-24          [-1, 128, 32, 32]           8,192
#       BatchNorm2d-25          [-1, 128, 32, 32]             256
#              ReLU-26          [-1, 128, 32, 32]               0
#        BasicBlock-27          [-1, 128, 32, 32]               0
#            Conv2d-28          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-29          [-1, 128, 32, 32]             256
#              ReLU-30          [-1, 128, 32, 32]               0
#            Conv2d-31          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-32          [-1, 128, 32, 32]             256
#              ReLU-33          [-1, 128, 32, 32]               0
#        BasicBlock-34          [-1, 128, 32, 32]               0
#            Conv2d-35          [-1, 256, 16, 16]         294,912
#       BatchNorm2d-36          [-1, 256, 16, 16]             512
#              ReLU-37          [-1, 256, 16, 16]               0
#            Conv2d-38          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-39          [-1, 256, 16, 16]             512
#            Conv2d-40          [-1, 256, 16, 16]          32,768
#       BatchNorm2d-41          [-1, 256, 16, 16]             512
#              ReLU-42          [-1, 256, 16, 16]               0
#        BasicBlock-43          [-1, 256, 16, 16]               0
#            Conv2d-44          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-45          [-1, 256, 16, 16]             512
#              ReLU-46          [-1, 256, 16, 16]               0
#            Conv2d-47          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-48          [-1, 256, 16, 16]             512
#              ReLU-49          [-1, 256, 16, 16]               0
#        BasicBlock-50          [-1, 256, 16, 16]               0
#            Conv2d-51            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-52            [-1, 512, 8, 8]           1,024
#              ReLU-53            [-1, 512, 8, 8]               0
#            Conv2d-54            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-55            [-1, 512, 8, 8]           1,024
#            Conv2d-56            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-57            [-1, 512, 8, 8]           1,024
#              ReLU-58            [-1, 512, 8, 8]               0
#        BasicBlock-59            [-1, 512, 8, 8]               0
#            Conv2d-60            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-61            [-1, 512, 8, 8]           1,024
#              ReLU-62            [-1, 512, 8, 8]               0
#            Conv2d-63            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-64            [-1, 512, 8, 8]           1,024
#              ReLU-65            [-1, 512, 8, 8]               0
#        BasicBlock-66            [-1, 512, 8, 8]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 100]          51,300
#              ReLU-69                  [-1, 100]               0
#            Linear-70                   [-1, 50]           5,050
#              ReLU-71                   [-1, 50]               0
#            Linear-72                   [-1, 25]           1,275
#            ResNet-73                   [-1, 25]               0
#            Conv2d-74         [-1, 64, 128, 128]           9,408
#       BatchNorm2d-75         [-1, 64, 128, 128]             128
#              ReLU-76         [-1, 64, 128, 128]               0
#         MaxPool2d-77           [-1, 64, 64, 64]               0
#            Conv2d-78           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-79           [-1, 64, 64, 64]             128
#              ReLU-80           [-1, 64, 64, 64]               0
#            Conv2d-81           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-82           [-1, 64, 64, 64]             128
#              ReLU-83           [-1, 64, 64, 64]               0
#        BasicBlock-84           [-1, 64, 64, 64]               0
#            Conv2d-85           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-86           [-1, 64, 64, 64]             128
#              ReLU-87           [-1, 64, 64, 64]               0
#            Conv2d-88           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-89           [-1, 64, 64, 64]             128
#              ReLU-90           [-1, 64, 64, 64]               0
#        BasicBlock-91           [-1, 64, 64, 64]               0
#            Conv2d-92          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-93          [-1, 128, 32, 32]             256
#              ReLU-94          [-1, 128, 32, 32]               0
#            Conv2d-95          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-96          [-1, 128, 32, 32]             256
#            Conv2d-97          [-1, 128, 32, 32]           8,192
#       BatchNorm2d-98          [-1, 128, 32, 32]             256
#              ReLU-99          [-1, 128, 32, 32]               0
#       BasicBlock-100          [-1, 128, 32, 32]               0
#           Conv2d-101          [-1, 128, 32, 32]         147,456
#      BatchNorm2d-102          [-1, 128, 32, 32]             256
#             ReLU-103          [-1, 128, 32, 32]               0
#           Conv2d-104          [-1, 128, 32, 32]         147,456
#      BatchNorm2d-105          [-1, 128, 32, 32]             256
#             ReLU-106          [-1, 128, 32, 32]               0
#       BasicBlock-107          [-1, 128, 32, 32]               0
#           Conv2d-108          [-1, 256, 16, 16]         294,912
#      BatchNorm2d-109          [-1, 256, 16, 16]             512
#             ReLU-110          [-1, 256, 16, 16]               0
#           Conv2d-111          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-112          [-1, 256, 16, 16]             512
#           Conv2d-113          [-1, 256, 16, 16]          32,768
#      BatchNorm2d-114          [-1, 256, 16, 16]             512
#             ReLU-115          [-1, 256, 16, 16]               0
#       BasicBlock-116          [-1, 256, 16, 16]               0
#           Conv2d-117          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-118          [-1, 256, 16, 16]             512
#             ReLU-119          [-1, 256, 16, 16]               0
#           Conv2d-120          [-1, 256, 16, 16]         589,824
#      BatchNorm2d-121          [-1, 256, 16, 16]             512
#             ReLU-122          [-1, 256, 16, 16]               0
#       BasicBlock-123          [-1, 256, 16, 16]               0
#           Conv2d-124            [-1, 512, 8, 8]       1,179,648
#      BatchNorm2d-125            [-1, 512, 8, 8]           1,024
#             ReLU-126            [-1, 512, 8, 8]               0
#           Conv2d-127            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-128            [-1, 512, 8, 8]           1,024
#           Conv2d-129            [-1, 512, 8, 8]         131,072
#      BatchNorm2d-130            [-1, 512, 8, 8]           1,024
#             ReLU-131            [-1, 512, 8, 8]               0
#       BasicBlock-132            [-1, 512, 8, 8]               0
#           Conv2d-133            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-134            [-1, 512, 8, 8]           1,024
#             ReLU-135            [-1, 512, 8, 8]               0
#           Conv2d-136            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-137            [-1, 512, 8, 8]           1,024
#             ReLU-138            [-1, 512, 8, 8]               0
#       BasicBlock-139            [-1, 512, 8, 8]               0
# AdaptiveAvgPool2d-140            [-1, 512, 1, 1]               0
#           Linear-141                  [-1, 100]          51,300
#             ReLU-142                  [-1, 100]               0
#           Linear-143                   [-1, 50]           5,050
#             ReLU-144                   [-1, 50]               0
#           Linear-145                   [-1, 25]           1,275
#           ResNet-146                   [-1, 25]               0
# ================================================================
# Total params: 22,468,274
# Trainable params: 22,468,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 164.01
# Params size (MB): 85.71
# Estimated Total Size (MB): 250.47
# ----------------------------------------------------------------

# %% [markdown]
# # Contrastive loss

# %%
# loss function
def loss_func(q, k, queue, t = 0.05):
    # t : temperature
    N = q.shape[0] # batch_size
    C = q.shape[1] # channel

    # bmm: batch matrix multiplication
    pos = torch.exp(torch.div(torch.bmm(q.view(N,1,C), k.view(N,C,1)).view(N,1),t))
    neg = torch.sum(torch.exp(torch.div(torch.mm(q.view(N,C),torch.t(queue)),t)),dim=1)

    # denominator is sum over pos and neg
    denominator = pos + neg

    return torch.mean(-torch.log(torch.div(pos,denominator)))

# %% [markdown]
# # Negative samples

# %%
# initialize the queue
queue = None
K = 8192 # K: number of negatives to store in queue

# fill the queue with negative samples
flag = 0
if queue is None:
    while True:
        with torch.no_grad():
            for img, _ in dataloaders['train']:
                # extract key samples
                xk = img[1].to(device)
                k = k_encoder(xk).detach()

                if queue is None:
                    queue = k
                else:
                    if queue.shape[0] < K: # queue < 8192
                        queue = torch.cat((queue,k),0)
                    else:
                        flag = 1 # stop filling the queue

                if flag == 1:
                    break 

        if flag == 1:
            break

queue = queue[:K]

# %%
# Sanity check
print('number of negative samples in queue : ',len(queue))
# Out:
# number of negative samples in queue :  8192

# %%
import time

optimizer = optim.Adam(q_encoder.parameters())
train_loss = []; val_loss = []

# define function to training
def train_model(q_encoder, k_encoder, num_epochs=1, st_epoch=0, queue=queue, sanity_check=False):
    momentum = 0.999
    start_time = time.time()
    q_encoder.train()
    
    best_loss = 1e10; best_train_loss = 1e10
    for epoch in range(st_epoch+1, num_epochs+1):
        print('Epoch {}/{}'.format(epoch, num_epochs)); print('-' * 10)
        since = time.time()

        # Each epoch has a training and validation phase
        for phase in ['train', 'validation']:
            running_loss = .0

            if phase == 'train': 
                q_encoder.train()   # Set query encoder to training mode
            else:                
                q_encoder.eval()    # Set query encoder to evaluate mode
            
            # Epoch
            for batch, (images, labels) in enumerate(dataloaders[phase], 1):
                if batch % 10 == 0:
                    print('{}/{}'.format(batch, len(dataloaders[phase])))
                
                # retrieve query and key
                xq = images[0].to(device)
                xk = images[1].to(device)
                
                k = k_encoder(xk).detach()
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase=='train'):
                    # get model ouputs
                    q = q_encoder(xq)
                    # normalize representations
                    q = torch.div(q, torch.norm(q, dim=1).reshape(-1, 1))
                    k = torch.div(k, torch.norm(k, dim=1).reshape(-1, 1))
                    # get loss value
                    loss = loss_func(q, k , queue)

                if phase == 'train': 
                    loss.backward()
                    optimizer.step()
                
                running_loss += loss

                # update the queue
                queue = torch.cat((queue, k), 0)

                if queue.shape[0] > K:
                    queue = queue[256:, :]
                
                # update k_encoder
                for q_params, k_params in zip(q_encoder.parameters(), k_encoder.parameters()):
                    k_params.data.copy_(momentum*k_params + q_params*(1.0-momentum))
                    
            epoch_loss = running_loss / len(image_datasets[phase])
            print('{} loss: {:.4f}'.format(phase, epoch_loss))
            
            if phase == 'train':
                train_loss.append(epoch_loss)    
                if epoch % 50 == 0:
                    print(f"saving epoch {epoch}'s train model to {checkpoint_path_1}")
                    save(ckpt_dir=q_encoder_path, model=q_encoder, optim=optimizer, epoch=epoch)
                    save(ckpt_dir=k_encoder_path, model=k_encoder, optim=optimizer, epoch=epoch)
            else:
                val_loss.append(epoch_loss)
                if epoch_loss < best_loss:
                    print(f"saving best loss model to {checkpoint_path_1}")
                    best_loss = epoch_loss
                    save(ckpt_dir=q_encoder_path, model=q_encoder, optim=optimizer, epoch=epoch)
                    save(ckpt_dir=k_encoder_path, model=k_encoder, optim=optimizer, epoch=epoch)

    return q_encoder, k_encoder

# %%
q_encoder, optimizer, qst_epoch = load(ckpt_dir=q_encoder_path, model=q_encoder, optim=optimizer)
k_encoder, optimizer, kst_epoch = load(ckpt_dir=k_encoder_path, model=k_encoder, optim=optimizer)

print(qst_epoch, kst_epoch)
# Out:
# 489 489

# %%
q_encoder, k_encoder = train_model(q_encoder, k_encoder, num_epochs=500, st_epoch=qst_epoch)

# %% [markdown]
# # Representation vector T-SNE visualization

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2)

def plot_vecs_n_labels(v, labels, fname):
    fig = plt.figure(figsize = (10,10))
    plt.axis('off')
    sn.set_style('darkgrid')
    sn.scatterplot(v[:,0], v[:,1], hue=labels, legend='full', palette=sn.color_palette("bright", 4))
    plt.legend(['ADC', 'HGD', 'LGD', 'NOR'])
    plt.savefig(fname)

dataloaders['train'] = DataLoader(image_datasets['train'], 3000, True)

for x,y in dataloaders['train']:
    x = x.to(device)
    with torch.no_grad():
        pred = q_encoder(x)
    pred_tsne = tsne.fit_transform(pred.cpu().data)
    plot_vecs_n_labels(pred_tsne, y, 'tsen.png')
    break
# Out:
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Classifier 학습을 위한 Dataset

# %%
batch_size = 128; test_batch_size = 1

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((256,256)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.590, 0.351, 0.259],
                                 std=[0.241, 0.199, 0.163])
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.590, 0.351, 0.259],
                                 std=[0.241, 0.199, 0.163])
    ]),
    'test':
    transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.590, 0.351, 0.259],
                                 std=[0.241, 0.199, 0.163])
    ])
}

image_datasets = {
    'train': ImageFolder(root=train_path, transform=data_transforms['train'], target_transform=None),
    'validation': ImageFolder(root=valid_path, transform=data_transforms['validation'], target_transform=None),
    'test': ImageFolder(root=test_path, transform=data_transforms['test'], target_transform=None),
}

dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=batch_size, shuffle=True, num_workers=8),
    'validation': DataLoader(image_datasets['validation'], batch_size=batch_size, shuffle=False, num_workers=8),
    'test': DataLoader(image_datasets['test'], batch_size=test_batch_size, shuffle=False, num_workers=8)
}

# %% [markdown]
# # Pretained model + Classifier

# %%
# Removing the projection head of q_encoder 
if len(nn.Sequential(*list(q_encoder.module.fc.children()))) == 5:
    q_encoder.module.fc = nn.Sequential(*list(q_encoder.module.fc.children())[:-3])

# %%
print(*list(q_encoder.module.fc))
# Out:
# Linear(in_features=512, out_features=100, bias=True) ReLU(inplace=True)

# %%
# define Linear Classifier for transfer learning
class LinearClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = torch.nn.Linear(100,4)

    def forward(self, x):
        x = self.fc1(x)
        return x

linear_classifier = LinearClassifier().to(device)

# %% [markdown]
# # Classifier 학습

# %%
classifier_chk_path = os.path.join(base_dir, 'classifier_chk_path')

import time

# training LinearClassifier
linear_loss_func = nn.CrossEntropyLoss()
linear_opt = optim.SGD(linear_classifier.parameters(), lr=0.1, momentum=0.9, weight_decay=1e-6)
train_loss = []; val_loss = []

# define function to training
def train_classifier(num_epochs=1, st_epoch=0):
    momentum = 0.999
    start_time = time.time()
    q_encoder.train()
    
    best_loss = 1e10; best_train_loss = 1e10
    for epoch in range(st_epoch+1, num_epochs+1):
        print('Epoch {}/{}'.format(epoch, num_epochs)); print('-' * 10)
        since = time.time()
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'validation']:
            running_loss = 0; running_metric = 0

            if phase == 'train': 
                linear_classifier.train()   # Set query encoder to training mode
            else:                
                linear_classifier.eval()    # Set query encoder to evaluate mode
            
            # Epoch
            for batch, (images, labels) in enumerate(dataloaders[phase], 1):
                if batch % 10 == 0:
                    print('{}/{}'.format(batch, len(dataloaders[phase])))
                
                input = images.to(device)
                label = labels.to(device)

                with torch.no_grad():
                    output_encoder = q_encoder(input)
                
                linear_opt.zero_grad()
                pred = linear_classifier(output_encoder)
                loss = linear_loss_func(pred, label)
                running_loss += loss

                if phase == 'train':                    
                    loss.backward()
                    linear_opt.step()      
                    
            
                pred = pred.argmax(1, keepdim=True)
                metric = pred.eq(label.view_as(pred)).sum().item()
                running_metric += metric

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_metric = running_metric / len(image_datasets[phase])

            if phase == 'train':
                train_loss.append(epoch_loss)
                print('{} loss: {:.4f}, acc: {:.4f}'.format(phase, epoch_loss, epoch_metric))
            else:
                val_loss.append(epoch_loss)
                print('{} loss: {:.4f}, acc: {:.4f}'.format(phase, epoch_loss, epoch_metric))
                if epoch_loss < best_loss:
                    print(f"saving best loss model to {classifier_chk_path}")
                    best_loss = epoch_loss
                    save(ckpt_dir=classifier_chk_path, model=linear_classifier, optim=optimizer, epoch=epoch)

    return linear_classifier

# %%
trained_classifier = train_classifier(num_epochs=500)
# Out:
# Epoch 1/500
# ----------
# 10/19
# train loss: 0.0429
# validation loss: 0.0883, acc: 0.4267
# saving best loss model to /home/sundongk/Self-supervised_contrastive_learning/classifier_chk_path
# Epoch 2/500
# ----------
# 10/19
# train loss: 0.0398
# validation loss: 0.1012, acc: 0.3733
# Epoch 3/500
# ----------
# 10/19
# train loss: 0.0285
# validation loss: 0.0833, acc: 0.3633
# saving best loss model to /home/sundongk/Self-supervised_contrastive_learning/classifier_chk_path
# Epoch 4/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.1559, acc: 0.2700
# Epoch 5/500
# ----------
# 10/19
# train loss: 0.0478
# validation loss: 0.1616, acc: 0.3067
# Epoch 6/500
# ----------
# 10/19
# train loss: 0.0361
# validation loss: 0.1222, acc: 0.3533
# Epoch 7/500
# ----------
# 10/19
# train loss: 0.0328
# validation loss: 0.0944, acc: 0.4033
# Epoch 8/500
# ----------
# 10/19
# train loss: 0.0274
# validation loss: 0.0649, acc: 0.4433
# saving best loss model to /home/sundongk/Self-supervised_contrastive_learning/classifier_chk_path
# Epoch 9/500
# ----------
# 10/19
# train loss: 0.0283
# validation loss: 0.1063, acc: 0.3600
# Epoch 10/500
# ----------
# 10/19
# train loss: 0.0365
# validation loss: 0.0928, acc: 0.4100
# Epoch 11/500
# ----------
# 10/19
# train loss: 0.0400
# validation loss: 0.0756, acc: 0.4100
# Epoch 12/500
# ----------
# 10/19
# train loss: 0.0535
# validation loss: 0.1057, acc: 0.4367
# Epoch 13/500
# ----------
# 10/19
# train loss: 0.0524
# validation loss: 0.1109, acc: 0.4133
# Epoch 14/500
# ----------
# 10/19
# train loss: 0.0377
# validation loss: 0.1153, acc: 0.3967
# Epoch 15/500
# ----------
# 10/19
# train loss: 0.0501
# validation loss: 0.1016, acc: 0.4367
# Epoch 16/500
# ----------
# 10/19
# train loss: 0.0381
# validation loss: 0.1173, acc: 0.3633
# Epoch 17/500
# ----------
# 10/19
# train loss: 0.0434
# validation loss: 0.1399, acc: 0.3533
# Epoch 18/500
# ----------
# 10/19
# train loss: 0.0331
# validation loss: 0.1110, acc: 0.3800
# Epoch 19/500
# ----------
# 10/19
# train loss: 0.0489
# validation loss: 0.0826, acc: 0.3933
# Epoch 20/500
# ----------
# 10/19
# train loss: 0.0400
# validation loss: 0.1035, acc: 0.4033
# Epoch 21/500
# ----------
# 10/19
# train loss: 0.0346
# validation loss: 0.0980, acc: 0.4433
# Epoch 22/500
# ----------
# 10/19
# train loss: 0.0542
# validation loss: 0.1303, acc: 0.4233
# Epoch 23/500
# ----------
# 10/19
# train loss: 0.0524
# validation loss: 0.1704, acc: 0.3700
# Epoch 24/500
# ----------
# 10/19
# train loss: 0.0519
# validation loss: 0.1555, acc: 0.4333
# Epoch 25/500
# ----------
# 10/19
# train loss: 0.0589
# validation loss: 0.1667, acc: 0.3467
# Epoch 26/500
# ----------
# 10/19
# train loss: 0.0411
# validation loss: 0.1055, acc: 0.3833
# Epoch 27/500
# ----------
# 10/19
# train loss: 0.0288
# validation loss: 0.0853, acc: 0.4167
# Epoch 28/500
# ----------
# 10/19
# train loss: 0.0295
# validation loss: 0.0602, acc: 0.4533
# saving best loss model to /home/sundongk/Self-supervised_contrastive_learning/classifier_chk_path
# Epoch 29/500
# ----------
# 10/19
# train loss: 0.0394
# validation loss: 0.1126, acc: 0.3100
# Epoch 30/500
# ----------
# 10/19
# train loss: 0.0319
# validation loss: 0.0770, acc: 0.4300
# Epoch 31/500
# ----------
# 10/19
# train loss: 0.0342
# validation loss: 0.1569, acc: 0.3300
# Epoch 32/500
# ----------
# 10/19
# train loss: 0.0333
# validation loss: 0.0850, acc: 0.4033
# Epoch 33/500
# ----------
# 10/19
# train loss: 0.0448
# validation loss: 0.1065, acc: 0.4033
# Epoch 34/500
# ----------
# 10/19
# train loss: 0.0594
# validation loss: 0.1154, acc: 0.4400
# Epoch 35/500
# ----------
# 10/19
# train loss: 0.0510
# validation loss: 0.1555, acc: 0.3733
# Epoch 36/500
# ----------
# 10/19
# train loss: 0.0457
# validation loss: 0.1492, acc: 0.3433
# Epoch 37/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.1104, acc: 0.3233
# Epoch 38/500
# ----------
# 10/19
# train loss: 0.0355
# validation loss: 0.0888, acc: 0.4300
# Epoch 39/500
# ----------
# 10/19
# train loss: 0.0436
# validation loss: 0.1049, acc: 0.4300
# Epoch 40/500
# ----------
# 10/19
# train loss: 0.0434
# validation loss: 0.0918, acc: 0.4400
# Epoch 41/500
# ----------
# 10/19
# train loss: 0.0313
# validation loss: 0.1089, acc: 0.4067
# Epoch 42/500
# ----------
# 10/19
# train loss: 0.0462
# validation loss: 0.1841, acc: 0.3667
# Epoch 43/500
# ----------
# 10/19
# train loss: 0.0448
# validation loss: 0.1750, acc: 0.2533
# Epoch 44/500
# ----------
# 10/19
# train loss: 0.0442
# validation loss: 0.0970, acc: 0.3467
# Epoch 45/500
# ----------
# 10/19
# train loss: 0.0458
# validation loss: 0.1526, acc: 0.3367
# Epoch 46/500
# ----------
# 10/19
# train loss: 0.0518
# validation loss: 0.1251, acc: 0.4433
# Epoch 47/500
# ----------
# 10/19
# train loss: 0.0403
# validation loss: 0.1305, acc: 0.3500
# Epoch 48/500
# ----------
# 10/19
# train loss: 0.0366
# validation loss: 0.1113, acc: 0.3833
# Epoch 49/500
# ----------
# 10/19
# train loss: 0.0457
# validation loss: 0.1030, acc: 0.4333
# Epoch 50/500
# ----------
# 10/19
# train loss: 0.0311
# validation loss: 0.1198, acc: 0.4333
# Epoch 51/500
# ----------
# 10/19
# train loss: 0.0373
# validation loss: 0.1811, acc: 0.3700
# Epoch 52/500
# ----------
# 10/19
# train loss: 0.0552
# validation loss: 0.1810, acc: 0.2667
# Epoch 53/500
# ----------
# 10/19
# train loss: 0.0635
# validation loss: 0.1992, acc: 0.2833
# Epoch 54/500
# ----------
# 10/19
# train loss: 0.0468
# validation loss: 0.1270, acc: 0.3833
# Epoch 55/500
# ----------
# 10/19
# train loss: 0.0370
# validation loss: 0.1335, acc: 0.3800
# Epoch 56/500
# ----------
# 10/19
# train loss: 0.0404
# validation loss: 0.1505, acc: 0.3833
# Epoch 57/500
# ----------
# 10/19
# train loss: 0.0449
# validation loss: 0.1368, acc: 0.3433
# Epoch 58/500
# ----------
# 10/19
# train loss: 0.0333
# validation loss: 0.1212, acc: 0.3533
# Epoch 59/500
# ----------
# 10/19
# train loss: 0.0390
# validation loss: 0.1295, acc: 0.3400
# Epoch 60/500
# ----------
# 10/19
# train loss: 0.0515
# validation loss: 0.1335, acc: 0.3367
# Epoch 61/500
# ----------
# 10/19
# train loss: 0.0430
# validation loss: 0.1458, acc: 0.3833
# Epoch 62/500
# ----------
# 10/19
# train loss: 0.0385
# validation loss: 0.1041, acc: 0.3700
# Epoch 63/500
# ----------
# 10/19
# train loss: 0.0449
# validation loss: 0.0992, acc: 0.4667
# Epoch 64/500
# ----------
# 10/19
# train loss: 0.0347
# validation loss: 0.0732, acc: 0.4100
# Epoch 65/500
# ----------
# 10/19
# train loss: 0.0400
# validation loss: 0.1197, acc: 0.3333
# Epoch 66/500
# ----------
# 10/19
# train loss: 0.0290
# validation loss: 0.1607, acc: 0.3733
# Epoch 67/500
# ----------
# 10/19
# train loss: 0.0304
# validation loss: 0.0759, acc: 0.3967
# Epoch 68/500
# ----------
# 10/19
# train loss: 0.0417
# validation loss: 0.1031, acc: 0.4167
# Epoch 69/500
# ----------
# 10/19
# train loss: 0.0415
# validation loss: 0.0946, acc: 0.3933
# Epoch 70/500
# ----------
# 10/19
# train loss: 0.0325
# validation loss: 0.0700, acc: 0.4333
# Epoch 71/500
# ----------
# 10/19
# train loss: 0.0674
# validation loss: 0.1358, acc: 0.4700
# Epoch 72/500
# ----------
# 10/19
# train loss: 0.0546
# validation loss: 0.1185, acc: 0.4133
# Epoch 73/500
# ----------
# 10/19
# train loss: 0.0374
# validation loss: 0.1046, acc: 0.3833
# Epoch 74/500
# ----------
# 10/19
# train loss: 0.0353
# validation loss: 0.1634, acc: 0.2667
# Epoch 75/500
# ----------
# 10/19
# train loss: 0.0619
# validation loss: 0.1122, acc: 0.4133
# Epoch 76/500
# ----------
# 10/19
# train loss: 0.0331
# validation loss: 0.1070, acc: 0.4467
# Epoch 77/500
# ----------
# 10/19
# train loss: 0.0435
# validation loss: 0.0921, acc: 0.4167
# Epoch 78/500
# ----------
# 10/19
# train loss: 0.0388
# validation loss: 0.1180, acc: 0.3467
# Epoch 79/500
# ----------
# 10/19
# train loss: 0.0401
# validation loss: 0.1274, acc: 0.3400
# Epoch 80/500
# ----------
# 10/19
# train loss: 0.0389
# validation loss: 0.1482, acc: 0.3733
# Epoch 81/500
# ----------
# 10/19
# train loss: 0.0310
# validation loss: 0.0866, acc: 0.4300
# Epoch 82/500
# ----------
# 10/19
# train loss: 0.0238
# validation loss: 0.0670, acc: 0.4333
# Epoch 83/500
# ----------
# 10/19
# train loss: 0.0288
# validation loss: 0.0779, acc: 0.4000
# Epoch 84/500
# ----------
# 10/19
# train loss: 0.0313
# validation loss: 0.0890, acc: 0.4300
# Epoch 85/500
# ----------
# 10/19
# train loss: 0.0345
# validation loss: 0.1117, acc: 0.4067
# Epoch 86/500
# ----------
# 10/19
# train loss: 0.0545
# validation loss: 0.1957, acc: 0.3600
# Epoch 87/500
# ----------
# 10/19
# train loss: 0.0478
# validation loss: 0.1233, acc: 0.4133
# Epoch 88/500
# ----------
# 10/19
# train loss: 0.0421
# validation loss: 0.1256, acc: 0.3333
# Epoch 89/500
# ----------
# 10/19
# train loss: 0.0448
# validation loss: 0.1233, acc: 0.4467
# Epoch 90/500
# ----------
# 10/19
# train loss: 0.0443
# validation loss: 0.0869, acc: 0.4500
# Epoch 91/500
# ----------
# 10/19
# train loss: 0.0393
# validation loss: 0.1089, acc: 0.4667
# Epoch 92/500
# ----------
# 10/19
# train loss: 0.0677
# validation loss: 0.1671, acc: 0.3867
# Epoch 93/500
# ----------
# 10/19
# train loss: 0.0482
# validation loss: 0.1036, acc: 0.4000
# Epoch 94/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.1163, acc: 0.4000
# Epoch 95/500
# ----------
# 10/19
# train loss: 0.0290
# validation loss: 0.1037, acc: 0.3767
# Epoch 96/500
# ----------
# 10/19
# train loss: 0.0274
# validation loss: 0.0609, acc: 0.4333
# Epoch 97/500
# ----------
# 10/19
# train loss: 0.0309
# validation loss: 0.0743, acc: 0.4000
# Epoch 98/500
# ----------
# 10/19
# train loss: 0.0346
# validation loss: 0.1298, acc: 0.4067
# Epoch 99/500
# ----------
# 10/19
# train loss: 0.0702
# validation loss: 0.2024, acc: 0.4167
# Epoch 100/500
# ----------
# 10/19
# train loss: 0.0486
# validation loss: 0.1141, acc: 0.3933
# Epoch 101/500
# ----------
# 10/19
# train loss: 0.0374
# validation loss: 0.1266, acc: 0.3667
# Epoch 102/500
# ----------
# 10/19
# train loss: 0.0569
# validation loss: 0.0984, acc: 0.4300
# Epoch 103/500
# ----------
# 10/19
# train loss: 0.0503
# validation loss: 0.1029, acc: 0.4367
# Epoch 104/500
# ----------
# 10/19
# train loss: 0.0341
# validation loss: 0.1095, acc: 0.3533
# Epoch 105/500
# ----------
# 10/19
# train loss: 0.0315
# validation loss: 0.0952, acc: 0.3867
# Epoch 106/500
# ----------
# 10/19
# train loss: 0.0348
# validation loss: 0.0774, acc: 0.4500
# Epoch 107/500
# ----------
# 10/19
# train loss: 0.0375
# validation loss: 0.1576, acc: 0.3600
# Epoch 108/500
# ----------
# 10/19
# train loss: 0.0475
# validation loss: 0.1052, acc: 0.3800
# Epoch 109/500
# ----------
# 10/19
# train loss: 0.0347
# validation loss: 0.1439, acc: 0.3000
# Epoch 110/500
# ----------
# 10/19
# train loss: 0.0315
# validation loss: 0.0842, acc: 0.4267
# Epoch 111/500
# ----------
# 10/19
# train loss: 0.0443
# validation loss: 0.0903, acc: 0.3967
# Epoch 112/500
# ----------
# 10/19
# train loss: 0.0485
# validation loss: 0.1096, acc: 0.4000
# Epoch 113/500
# ----------
# 10/19
# train loss: 0.0423
# validation loss: 0.1108, acc: 0.3633
# Epoch 114/500
# ----------
# 10/19
# train loss: 0.0408
# validation loss: 0.1031, acc: 0.3733
# Epoch 115/500
# ----------
# 10/19
# train loss: 0.0382
# validation loss: 0.1167, acc: 0.3900
# Epoch 116/500
# ----------
# 10/19
# train loss: 0.0522
# validation loss: 0.0928, acc: 0.4167
# Epoch 117/500
# ----------
# 10/19
# train loss: 0.0484
# validation loss: 0.1411, acc: 0.3900
# Epoch 118/500
# ----------
# 10/19
# train loss: 0.0372
# validation loss: 0.1839, acc: 0.3767
# Epoch 119/500
# ----------
# 10/19
# train loss: 0.0413
# validation loss: 0.1844, acc: 0.3667
# Epoch 120/500
# ----------
# 10/19
# train loss: 0.0345
# validation loss: 0.1162, acc: 0.3167
# Epoch 121/500
# ----------
# 10/19
# train loss: 0.0363
# validation loss: 0.0981, acc: 0.4200
# Epoch 122/500
# ----------
# 10/19
# train loss: 0.0313
# validation loss: 0.0817, acc: 0.4033
# Epoch 123/500
# ----------
# 10/19
# train loss: 0.0423
# validation loss: 0.1473, acc: 0.2800
# Epoch 124/500
# ----------
# 10/19
# train loss: 0.0402
# validation loss: 0.1347, acc: 0.3100
# Epoch 125/500
# ----------
# 10/19
# train loss: 0.0407
# validation loss: 0.1415, acc: 0.3767
# Epoch 126/500
# ----------
# 10/19
# train loss: 0.0344
# validation loss: 0.0740, acc: 0.3767
# Epoch 127/500
# ----------
# 10/19
# train loss: 0.0287
# validation loss: 0.1368, acc: 0.3867
# Epoch 128/500
# ----------
# 10/19
# train loss: 0.0553
# validation loss: 0.0994, acc: 0.4300
# Epoch 129/500
# ----------
# 10/19
# train loss: 0.0532
# validation loss: 0.1190, acc: 0.3700
# Epoch 130/500
# ----------
# 10/19
# train loss: 0.0327
# validation loss: 0.0996, acc: 0.4433
# Epoch 131/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.0830, acc: 0.4200
# Epoch 132/500
# ----------
# 10/19
# train loss: 0.0634
# validation loss: 0.1427, acc: 0.4433
# Epoch 133/500
# ----------
# 10/19
# train loss: 0.0603
# validation loss: 0.1771, acc: 0.3167
# Epoch 134/500
# ----------
# 10/19
# train loss: 0.0588
# validation loss: 0.1261, acc: 0.3933
# Epoch 135/500
# ----------
# 10/19
# train loss: 0.0411
# validation loss: 0.0921, acc: 0.3967
# Epoch 136/500
# ----------
# 10/19
# train loss: 0.0271
# validation loss: 0.0881, acc: 0.4433
# Epoch 137/500
# ----------
# 10/19
# train loss: 0.0306
# validation loss: 0.0840, acc: 0.3533
# Epoch 138/500
# ----------
# 10/19
# train loss: 0.0568
# validation loss: 0.1360, acc: 0.4300
# Epoch 139/500
# ----------
# 10/19
# train loss: 0.0316
# validation loss: 0.0903, acc: 0.4133
# Epoch 140/500
# ----------
# 10/19
# train loss: 0.0425
# validation loss: 0.1658, acc: 0.3767
# Epoch 141/500
# ----------
# 10/19
# train loss: 0.0616
# validation loss: 0.1515, acc: 0.4267
# Epoch 142/500
# ----------
# 10/19
# train loss: 0.0354
# validation loss: 0.1091, acc: 0.3800
# Epoch 143/500
# ----------
# 10/19
# train loss: 0.0377
# validation loss: 0.1075, acc: 0.4167
# Epoch 144/500
# ----------
# 10/19
# train loss: 0.0405
# validation loss: 0.1198, acc: 0.4600
# Epoch 145/500
# ----------
# 10/19
# train loss: 0.0604
# validation loss: 0.1996, acc: 0.3633
# Epoch 146/500
# ----------
# 10/19
# train loss: 0.0529
# validation loss: 0.1474, acc: 0.4067
# Epoch 147/500
# ----------
# 10/19
# train loss: 0.0655
# validation loss: 0.1795, acc: 0.4067
# Epoch 148/500
# ----------
# 10/19
# train loss: 0.0581
# validation loss: 0.1381, acc: 0.3967
# Epoch 149/500
# ----------
# 10/19
# train loss: 0.0515
# validation loss: 0.1052, acc: 0.4100
# Epoch 150/500
# ----------
# 10/19
# train loss: 0.0382
# validation loss: 0.1124, acc: 0.3800
# Epoch 151/500
# ----------
# 10/19
# train loss: 0.0388
# validation loss: 0.2532, acc: 0.3533
# Epoch 152/500
# ----------
# 10/19
# train loss: 0.0699
# validation loss: 0.1252, acc: 0.4033
# Epoch 153/500
# ----------
# 10/19
# train loss: 0.0487
# validation loss: 0.1267, acc: 0.4467
# Epoch 154/500
# ----------
# 10/19
# train loss: 0.0413
# validation loss: 0.1342, acc: 0.3900
# Epoch 155/500
# ----------
# 10/19
# train loss: 0.0580
# validation loss: 0.2136, acc: 0.3533
# Epoch 156/500
# ----------
# 10/19
# train loss: 0.0493
# validation loss: 0.1061, acc: 0.3900
# Epoch 157/500
# ----------
# 10/19
# train loss: 0.0380
# validation loss: 0.0917, acc: 0.4467
# Epoch 158/500
# ----------
# 10/19
# train loss: 0.0367
# validation loss: 0.0857, acc: 0.4333
# Epoch 159/500
# ----------
# 10/19
# train loss: 0.0365
# validation loss: 0.0909, acc: 0.4300
# Epoch 160/500
# ----------
# 10/19
# train loss: 0.0359
# validation loss: 0.1392, acc: 0.3933
# Epoch 161/500
# ----------
# 10/19
# train loss: 0.0511
# validation loss: 0.1942, acc: 0.3200
# Epoch 162/500
# ----------
# 10/19
# train loss: 0.0584
# validation loss: 0.1297, acc: 0.4100
# Epoch 163/500
# ----------
# 10/19
# train loss: 0.0323
# validation loss: 0.0894, acc: 0.4300
# Epoch 164/500
# ----------
# 10/19
# train loss: 0.0373
# validation loss: 0.1045, acc: 0.4167
# Epoch 165/500
# ----------
# 10/19
# train loss: 0.0432
# validation loss: 0.1246, acc: 0.4467
# Epoch 166/500
# ----------
# 10/19
# train loss: 0.0300
# validation loss: 0.0879, acc: 0.4400
# Epoch 167/500
# ----------
# 10/19
# train loss: 0.0431
# validation loss: 0.0891, acc: 0.4367
# Epoch 168/500
# ----------
# 10/19
# train loss: 0.0342
# validation loss: 0.1751, acc: 0.3900
# Epoch 169/500
# ----------
# 10/19
# train loss: 0.0377
# validation loss: 0.0916, acc: 0.3833
# Epoch 170/500
# ----------
# 10/19
# train loss: 0.0489
# validation loss: 0.1105, acc: 0.4267
# Epoch 171/500
# ----------
# 10/19
# train loss: 0.0382
# validation loss: 0.0992, acc: 0.4367
# Epoch 172/500
# ----------
# 10/19
# train loss: 0.0542
# validation loss: 0.1094, acc: 0.4400
# Epoch 173/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.1626, acc: 0.3867
# Epoch 174/500
# ----------
# 10/19
# train loss: 0.0363
# validation loss: 0.0977, acc: 0.3667
# Epoch 175/500
# ----------
# 10/19
# train loss: 0.0362
# validation loss: 0.1013, acc: 0.4000
# Epoch 176/500
# ----------
# 10/19
# train loss: 0.0422
# validation loss: 0.0985, acc: 0.4300
# Epoch 177/500
# ----------
# 10/19
# train loss: 0.0391
# validation loss: 0.0870, acc: 0.4467
# Epoch 178/500
# ----------
# 10/19
# train loss: 0.0349
# validation loss: 0.1322, acc: 0.3233
# Epoch 179/500
# ----------
# 10/19
# train loss: 0.0374
# validation loss: 0.0929, acc: 0.3600
# Epoch 180/500
# ----------
# 10/19
# train loss: 0.0465
# validation loss: 0.1547, acc: 0.3300
# Epoch 181/500
# ----------
# 10/19
# train loss: 0.0502
# validation loss: 0.1108, acc: 0.3667
# Epoch 182/500
# ----------
# 10/19
# train loss: 0.0393
# validation loss: 0.1171, acc: 0.3433
# Epoch 183/500
# ----------
# 10/19
# train loss: 0.0406
# validation loss: 0.0907, acc: 0.4067
# Epoch 184/500
# ----------
# 10/19
# train loss: 0.0323
# validation loss: 0.1582, acc: 0.2867
# Epoch 185/500
# ----------
# 10/19
# train loss: 0.0406
# validation loss: 0.1215, acc: 0.4233
# Epoch 186/500
# ----------
# 10/19
# train loss: 0.0334
# validation loss: 0.0789, acc: 0.3867
# Epoch 187/500
# ----------
# 10/19
# train loss: 0.0232
# validation loss: 0.0701, acc: 0.4033
# Epoch 188/500
# ----------
# 10/19
# train loss: 0.0488
# validation loss: 0.1179, acc: 0.4367
# Epoch 189/500
# ----------
# 10/19
# train loss: 0.0480
# validation loss: 0.1040, acc: 0.3633
# Epoch 190/500
# ----------
# 10/19
# train loss: 0.0277
# validation loss: 0.0993, acc: 0.4367
# Epoch 191/500
# ----------
# 10/19
# train loss: 0.0325
# validation loss: 0.0980, acc: 0.3933
# Epoch 192/500
# ----------
# 10/19
# train loss: 0.0481
# validation loss: 0.1560, acc: 0.2933
# Epoch 193/500
# ----------
# 10/19
# train loss: 0.0514
# validation loss: 0.1305, acc: 0.3467
# Epoch 194/500
# ----------
# 10/19
# train loss: 0.0526
# validation loss: 0.1316, acc: 0.3367
# Epoch 195/500
# ----------
# 10/19
# train loss: 0.0393
# validation loss: 0.0997, acc: 0.4233
# Epoch 196/500
# ----------
# 10/19
# train loss: 0.0459
# validation loss: 0.1136, acc: 0.3767
# Epoch 197/500
# ----------
# 10/19
# train loss: 0.0562
# validation loss: 0.1193, acc: 0.4567
# Epoch 198/500
# ----------
# 10/19
# train loss: 0.0412
# validation loss: 0.1121, acc: 0.4067
# Epoch 199/500
# ----------
# 10/19
# train loss: 0.0484
# validation loss: 0.1458, acc: 0.3533
# Epoch 200/500
# ----------
# 10/19
# train loss: 0.0518
# validation loss: 0.1222, acc: 0.4100
# Epoch 201/500
# ----------
# 10/19
# train loss: 0.0382
# validation loss: 0.1053, acc: 0.4533
# Epoch 202/500
# ----------
# 10/19
# train loss: 0.0365
# validation loss: 0.0788, acc: 0.4133
# Epoch 203/500
# ----------
# 10/19
# train loss: 0.0369
# validation loss: 0.0935, acc: 0.3933
# Epoch 204/500
# ----------
# 10/19
# train loss: 0.0404
# validation loss: 0.1070, acc: 0.4200
# Epoch 205/500
# ----------
# 10/19
# train loss: 0.0464
# validation loss: 0.1270, acc: 0.4767
# Epoch 206/500
# ----------
# 10/19
# train loss: 0.0465
# validation loss: 0.1050, acc: 0.3933
# Epoch 207/500
# ----------
# 10/19
# train loss: 0.0311
# validation loss: 0.0817, acc: 0.3600
# Epoch 208/500
# ----------
# 10/19
# train loss: 0.0488
# validation loss: 0.1730, acc: 0.3900
# Epoch 209/500
# ----------
# 10/19
# train loss: 0.0511
# validation loss: 0.1363, acc: 0.4567
# Epoch 210/500
# ----------
# 10/19
# train loss: 0.0459
# validation loss: 0.1690, acc: 0.3733
# Epoch 211/500
# ----------
# 10/19
# train loss: 0.0380
# validation loss: 0.1239, acc: 0.3833
# Epoch 212/500
# ----------
# 10/19
# train loss: 0.0330
# validation loss: 0.0731, acc: 0.4500
# Epoch 213/500
# ----------
# 10/19
# train loss: 0.0315
# validation loss: 0.0745, acc: 0.3900
# Epoch 214/500
# ----------
# 10/19
# train loss: 0.0395
# validation loss: 0.1216, acc: 0.4100
# Epoch 215/500
# ----------
# 10/19
# train loss: 0.0307
# validation loss: 0.0682, acc: 0.4700
# Epoch 216/500
# ----------
# 10/19
# train loss: 0.0370
# validation loss: 0.1055, acc: 0.4200
# Epoch 217/500
# ----------
# 10/19
# train loss: 0.0454
# validation loss: 0.0947, acc: 0.4100
# Epoch 218/500
# ----------
# 10/19
# train loss: 0.0421
# validation loss: 0.1383, acc: 0.4000
# Epoch 219/500
# ----------
# 10/19
# train loss: 0.0346
# validation loss: 0.1002, acc: 0.3867
# Epoch 220/500
# ----------
# 10/19
# train loss: 0.0394
# validation loss: 0.1065, acc: 0.4267
# Epoch 221/500
# ----------
# 10/19
# train loss: 0.0337
# validation loss: 0.0848, acc: 0.3600
# Epoch 222/500
# ----------
# 10/19
# train loss: 0.0652
# validation loss: 0.1536, acc: 0.3467
# Epoch 223/500
# ----------
# 10/19
# train loss: 0.0423
# validation loss: 0.1083, acc: 0.4333
# Epoch 224/500
# ----------
# 10/19
# train loss: 0.0253
# validation loss: 0.1124, acc: 0.3167
# Epoch 225/500
# ----------
# 10/19
# train loss: 0.0346
# validation loss: 0.0785, acc: 0.3400
# Epoch 226/500
# ----------
# 10/19
# train loss: 0.0533
# validation loss: 0.1198, acc: 0.4067
# Epoch 227/500
# ----------
# 10/19
# train loss: 0.0406
# validation loss: 0.0938, acc: 0.4000
# Epoch 228/500
# ----------
# 10/19
# train loss: 0.0522
# validation loss: 0.1143, acc: 0.4400
# Epoch 229/500
# ----------
# 10/19
# train loss: 0.0395
# validation loss: 0.0996, acc: 0.4200
# Epoch 230/500
# ----------
# 10/19
# train loss: 0.0555
# validation loss: 0.1091, acc: 0.4500
# Epoch 231/500
# ----------
# 10/19
# train loss: 0.0439
# validation loss: 0.1074, acc: 0.4400
# Epoch 232/500
# ----------
# 10/19
# train loss: 0.0410
# validation loss: 0.1414, acc: 0.3733
# Epoch 233/500
# ----------
# 10/19
# train loss: 0.0541
# validation loss: 0.1453, acc: 0.3600
# Epoch 234/500
# ----------
# 10/19
# train loss: 0.0438
# validation loss: 0.1186, acc: 0.3733
# Epoch 235/500
# ----------
# 10/19
# train loss: 0.0463
# validation loss: 0.0951, acc: 0.4433
# Epoch 236/500
# ----------
# 10/19
# train loss: 0.0362
# validation loss: 0.1027, acc: 0.4333
# Epoch 237/500
# ----------
# 10/19
# train loss: 0.0353
# validation loss: 0.0889, acc: 0.3933
# Epoch 238/500
# ----------
# 10/19
# train loss: 0.0354
# validation loss: 0.1385, acc: 0.3567
# Epoch 239/500
# ----------
# 10/19
# train loss: 0.0357
# validation loss: 0.1085, acc: 0.4033
# Epoch 240/500
# ----------
# 10/19
# train loss: 0.0579
# validation loss: 0.1714, acc: 0.3100
# Epoch 241/500
# ----------
# 10/19
# train loss: 0.0489
# validation loss: 0.1407, acc: 0.3533
# Epoch 242/500
# ----------
# 10/19
# train loss: 0.0441
# validation loss: 0.1069, acc: 0.3933
# Epoch 243/500
# ----------
# 10/19
# train loss: 0.0627
# validation loss: 0.1108, acc: 0.4033
# Epoch 244/500
# ----------
# 10/19
# train loss: 0.0580
# validation loss: 0.1548, acc: 0.4100
# Epoch 245/500
# ----------
# 10/19
# train loss: 0.0448
# validation loss: 0.1113, acc: 0.4233
# Epoch 246/500
# ----------
# 10/19
# train loss: 0.0264
# validation loss: 0.1161, acc: 0.3333
# Epoch 247/500
# ----------
# 10/19
# train loss: 0.0493
# validation loss: 0.1454, acc: 0.3733
# Epoch 248/500
# ----------
# 10/19
# train loss: 0.0474
# validation loss: 0.1535, acc: 0.3467
# Epoch 249/500
# ----------
# 10/19
# train loss: 0.0402
# validation loss: 0.1133, acc: 0.4333
# Epoch 250/500
# ----------
# 10/19
# train loss: 0.0334
# validation loss: 0.1279, acc: 0.4233
# Epoch 251/500
# ----------
# 10/19
# train loss: 0.0519
# validation loss: 0.1382, acc: 0.3833
# Epoch 252/500
# ----------
# 10/19
# train loss: 0.0583
# validation loss: 0.1501, acc: 0.4200
# Epoch 253/500
# ----------
# 10/19
# train loss: 0.0481
# validation loss: 0.0941, acc: 0.4200
# Epoch 254/500
# ----------
# 10/19
# train loss: 0.0395
# validation loss: 0.1023, acc: 0.4267
# Epoch 255/500
# ----------
# 10/19
# train loss: 0.0345
# validation loss: 0.0944, acc: 0.4500
# Epoch 256/500
# ----------
# 10/19
# train loss: 0.0459
# validation loss: 0.1216, acc: 0.3800
# Epoch 257/500
# ----------
# 10/19
# train loss: 0.0434
# validation loss: 0.1107, acc: 0.4367
# Epoch 258/500
# ----------
# 10/19
# train loss: 0.0345
# validation loss: 0.0771, acc: 0.4467
# Epoch 259/500
# ----------
# 10/19
# train loss: 0.0319
# validation loss: 0.1259, acc: 0.3733
# Epoch 260/500
# ----------
# 10/19
# train loss: 0.0713
# validation loss: 0.1484, acc: 0.3567
# Epoch 261/500
# ----------
# 10/19
# train loss: 0.0355
# validation loss: 0.0888, acc: 0.4133
# Epoch 262/500
# ----------
# 10/19
# train loss: 0.0331
# validation loss: 0.1386, acc: 0.3167
# Epoch 263/500
# ----------
# 10/19
# train loss: 0.0385
# validation loss: 0.1310, acc: 0.2967
# Epoch 264/500
# ----------
# 10/19
# train loss: 0.0577
# validation loss: 0.1152, acc: 0.4067
# Epoch 265/500
# ----------
# 10/19
# train loss: 0.0642
# validation loss: 0.1733, acc: 0.4167
# Epoch 266/500
# ----------
# 10/19
# train loss: 0.0520
# validation loss: 0.0960, acc: 0.4300
# Epoch 267/500
# ----------
# 10/19
# train loss: 0.0305
# validation loss: 0.0946, acc: 0.3467
# Epoch 268/500
# ----------
# 10/19
# train loss: 0.0388
# validation loss: 0.0878, acc: 0.4333
# Epoch 269/500
# ----------
# 10/19
# train loss: 0.0338
# validation loss: 0.1314, acc: 0.4100
# Epoch 270/500
# ----------
# 10/19
# train loss: 0.0569
# validation loss: 0.1322, acc: 0.3767
# Epoch 271/500
# ----------
# 10/19
# train loss: 0.0363
# validation loss: 0.1275, acc: 0.4133
# Epoch 272/500
# ----------
# 10/19
# train loss: 0.0471
# validation loss: 0.1510, acc: 0.3367
# Epoch 273/500
# ----------
# 10/19
# train loss: 0.0429
# validation loss: 0.1379, acc: 0.3367
# Epoch 274/500
# ----------
# 10/19
# train loss: 0.0421
# validation loss: 0.0963, acc: 0.4333
# Epoch 275/500
# ----------
# 10/19
# train loss: 0.0571
# validation loss: 0.1317, acc: 0.4600
# Epoch 276/500
# ----------
# 10/19
# train loss: 0.0593
# validation loss: 0.2177, acc: 0.2467
# Epoch 277/500
# ----------
# 10/19
# train loss: 0.0481
# validation loss: 0.1410, acc: 0.3867
# Epoch 278/500
# ----------
# 10/19
# train loss: 0.0389
# validation loss: 0.1097, acc: 0.4233
# Epoch 279/500
# ----------
# 10/19
# train loss: 0.0402
# validation loss: 0.1293, acc: 0.3567
# Epoch 280/500
# ----------
# 10/19
# train loss: 0.0516
# validation loss: 0.1026, acc: 0.4267
# Epoch 281/500
# ----------
# 10/19
# train loss: 0.0326
# validation loss: 0.0885, acc: 0.3967
# Epoch 282/500
# ----------
# 10/19
# train loss: 0.0430
# validation loss: 0.1462, acc: 0.4100
# Epoch 283/500
# ----------
# 10/19
# train loss: 0.0476
# validation loss: 0.1102, acc: 0.4400
# Epoch 284/500
# ----------
# 10/19
# train loss: 0.0429
# validation loss: 0.1031, acc: 0.4233
# Epoch 285/500
# ----------
# 10/19
# train loss: 0.0392
# validation loss: 0.0998, acc: 0.3867
# Epoch 286/500
# ----------
# 10/19
# train loss: 0.0405
# validation loss: 0.1015, acc: 0.4100
# Epoch 287/500
# ----------
# 10/19
# train loss: 0.0374
# validation loss: 0.1751, acc: 0.3400
# Epoch 288/500
# ----------
# 10/19
# train loss: 0.0622
# validation loss: 0.1488, acc: 0.3700
# Epoch 289/500
# ----------
# 10/19
# train loss: 0.0398
# validation loss: 0.0811, acc: 0.4167
# Epoch 290/500
# ----------
# 10/19
# train loss: 0.0435
# validation loss: 0.1580, acc: 0.3500
# Epoch 291/500
# ----------
# 10/19
# train loss: 0.0363
# validation loss: 0.0813, acc: 0.4067
# Epoch 292/500
# ----------
# 10/19
# train loss: 0.0348
# validation loss: 0.1443, acc: 0.3500
# Epoch 293/500
# ----------
# 10/19
# train loss: 0.0464
# validation loss: 0.1246, acc: 0.4367
# Epoch 294/500
# ----------
# 10/19
# train loss: 0.0515
# validation loss: 0.1407, acc: 0.4067
# Epoch 295/500
# ----------
# 10/19
# train loss: 0.0345
# validation loss: 0.0881, acc: 0.4233
# Epoch 296/500
# ----------
# 10/19
# train loss: 0.0417
# validation loss: 0.1657, acc: 0.3267
# Epoch 297/500
# ----------
# 10/19
# train loss: 0.0368
# validation loss: 0.0991, acc: 0.4233
# Epoch 298/500
# ----------
# 10/19
# train loss: 0.0515
# validation loss: 0.1391, acc: 0.4400
# Epoch 299/500
# ----------
# 10/19
# train loss: 0.0522
# validation loss: 0.1315, acc: 0.3867
# Epoch 300/500
# ----------
# 10/19
# train loss: 0.0318
# validation loss: 0.0794, acc: 0.4567
# Epoch 301/500
# ----------
# 10/19
# train loss: 0.0295
# validation loss: 0.1091, acc: 0.3833
# Epoch 302/500
# ----------
# 10/19
# train loss: 0.0584
# validation loss: 0.1397, acc: 0.4500
# Epoch 303/500
# ----------
# 10/19
# train loss: 0.0589
# validation loss: 0.1484, acc: 0.3633
# Epoch 304/500
# ----------
# 10/19
# train loss: 0.0522
# validation loss: 0.1186, acc: 0.3733
# Epoch 305/500
# ----------
# 10/19
# train loss: 0.0504
# validation loss: 0.1242, acc: 0.4067
# Epoch 306/500
# ----------
# 10/19
# train loss: 0.0335
# validation loss: 0.1266, acc: 0.3200
# Epoch 307/500
# ----------
# 10/19
# train loss: 0.0402
# validation loss: 0.0999, acc: 0.3967
# Epoch 308/500
# ----------
# 10/19
# train loss: 0.0544
# validation loss: 0.1142, acc: 0.4333
# Epoch 309/500
# ----------
# 10/19
# train loss: 0.0422
# validation loss: 0.1096, acc: 0.4100
# Epoch 310/500
# ----------
# 10/19
# train loss: 0.0259
# validation loss: 0.1444, acc: 0.3167
# Epoch 311/500
# ----------
# 10/19
# train loss: 0.0535
# validation loss: 0.1342, acc: 0.3433
# Epoch 312/500
# ----------
# 10/19
# train loss: 0.0651
# validation loss: 0.2130, acc: 0.4100
# Epoch 313/500
# ----------
# 10/19
# train loss: 0.0487
# validation loss: 0.1834, acc: 0.3900
# Epoch 314/500
# ----------
# 10/19
# train loss: 0.0388
# validation loss: 0.0881, acc: 0.4333
# Epoch 315/500
# ----------
# 10/19
# train loss: 0.0317
# validation loss: 0.1352, acc: 0.2967
# Epoch 316/500
# ----------
# 10/19
# train loss: 0.0536
# validation loss: 0.1788, acc: 0.2700
# Epoch 317/500
# ----------
# 10/19
# train loss: 0.0428
# validation loss: 0.1383, acc: 0.3967
# Epoch 318/500
# ----------
# 10/19
# train loss: 0.0484
# validation loss: 0.1252, acc: 0.3900
# Epoch 319/500
# ----------
# 10/19
# train loss: 0.0376
# validation loss: 0.0938, acc: 0.3833
# Epoch 320/500
# ----------
# 10/19
# train loss: 0.0399
# validation loss: 0.1141, acc: 0.3633
# Epoch 321/500
# ----------
# 10/19
# train loss: 0.0359
# validation loss: 0.1123, acc: 0.3733
# Epoch 322/500
# ----------
# 10/19
# train loss: 0.0490
# validation loss: 0.1564, acc: 0.3133
# Epoch 323/500
# ----------
# 10/19
# train loss: 0.0508
# validation loss: 0.1391, acc: 0.4167
# Epoch 324/500
# ----------
# 10/19
# train loss: 0.0350
# validation loss: 0.1568, acc: 0.3800
# Epoch 325/500
# ----------
# 10/19
# train loss: 0.0403
# validation loss: 0.1255, acc: 0.3200
# Epoch 326/500
# ----------
# 10/19
# train loss: 0.0385
# validation loss: 0.0949, acc: 0.3900
# Epoch 327/500
# ----------
# 10/19
# train loss: 0.0373
# validation loss: 0.1194, acc: 0.4133
# Epoch 328/500
# ----------
# 10/19
# train loss: 0.0580
# validation loss: 0.1071, acc: 0.4300
# Epoch 329/500
# ----------
# 10/19
# train loss: 0.0413
# validation loss: 0.0935, acc: 0.4167
# Epoch 330/500
# ----------
# 10/19
# train loss: 0.0488
# validation loss: 0.1645, acc: 0.2900
# Epoch 331/500
# ----------
# 10/19
# train loss: 0.0578
# validation loss: 0.1057, acc: 0.4033
# Epoch 332/500
# ----------
# 10/19
# train loss: 0.0320
# validation loss: 0.1005, acc: 0.4300
# Epoch 333/500
# ----------
# 10/19
# train loss: 0.0286
# validation loss: 0.0962, acc: 0.4200
# Epoch 334/500
# ----------
# 10/19
# train loss: 0.0314
# validation loss: 0.0647, acc: 0.4300
# Epoch 335/500
# ----------
# 10/19
# train loss: 0.0522
# validation loss: 0.0979, acc: 0.4267
# Epoch 336/500
# ----------
# 10/19
# train loss: 0.0405
# validation loss: 0.0934, acc: 0.3633
# Epoch 337/500
# ----------
# 10/19
# train loss: 0.0415
# validation loss: 0.1291, acc: 0.4067
# Epoch 338/500
# ----------
# 10/19
# train loss: 0.0479
# validation loss: 0.1098, acc: 0.4167
# Epoch 339/500
# ----------
# 10/19
# train loss: 0.0305
# validation loss: 0.1031, acc: 0.3800
# Epoch 340/500
# ----------
# 10/19
# train loss: 0.0300
# validation loss: 0.0921, acc: 0.3833
# Epoch 341/500
# ----------
# 10/19
# train loss: 0.0331
# validation loss: 0.1200, acc: 0.2967
# Epoch 342/500
# ----------
# 10/19
# train loss: 0.0597
# validation loss: 0.2078, acc: 0.3000
# Epoch 343/500
# ----------
# 10/19
# train loss: 0.0487
# validation loss: 0.1395, acc: 0.3767
# Epoch 344/500
# ----------
# 10/19
# train loss: 0.0517
# validation loss: 0.1202, acc: 0.4067
# Epoch 345/500
# ----------
# 10/19
# train loss: 0.0392
# validation loss: 0.0935, acc: 0.4500
# Epoch 346/500
# ----------
# 10/19
# train loss: 0.0348
# validation loss: 0.0822, acc: 0.4300
# Epoch 347/500
# ----------
# 10/19
# train loss: 0.0309
# validation loss: 0.0740, acc: 0.4067
# Epoch 348/500
# ----------
# 10/19
# train loss: 0.0295
# validation loss: 0.1130, acc: 0.3467
# Epoch 349/500
# ----------
# 10/19
# train loss: 0.0385
# validation loss: 0.1480, acc: 0.2533
# Epoch 350/500
# ----------
# 10/19
# train loss: 0.0602
# validation loss: 0.1141, acc: 0.4067
# Epoch 351/500
# ----------
# 10/19
# train loss: 0.0355
# validation loss: 0.1066, acc: 0.3433
# Epoch 352/500
# ----------
# 10/19
# train loss: 0.0260
# validation loss: 0.0920, acc: 0.3867
# Epoch 353/500
# ----------
# 10/19
# train loss: 0.0331
# validation loss: 0.0755, acc: 0.4300
# Epoch 354/500
# ----------
# 10/19
# train loss: 0.0488
# validation loss: 0.1794, acc: 0.3300
# Epoch 355/500
# ----------
# 10/19
# train loss: 0.0567
# validation loss: 0.1218, acc: 0.4467
# Epoch 356/500
# ----------
# 10/19
# train loss: 0.0383
# validation loss: 0.0926, acc: 0.4533
# Epoch 357/500
# ----------
# 10/19
# train loss: 0.0306
# validation loss: 0.2024, acc: 0.2067
# Epoch 358/500
# ----------
# 10/19
# train loss: 0.0678
# validation loss: 0.0975, acc: 0.4433
# Epoch 359/500
# ----------
# 10/19
# train loss: 0.0443
# validation loss: 0.1436, acc: 0.2933
# Epoch 360/500
# ----------
# 10/19
# train loss: 0.0470
# validation loss: 0.1016, acc: 0.4333
# Epoch 361/500
# ----------
# 10/19
# train loss: 0.0380
# validation loss: 0.0957, acc: 0.4433
# Epoch 362/500
# ----------
# 10/19
# train loss: 0.0359
# validation loss: 0.0975, acc: 0.4267
# Epoch 363/500
# ----------
# 10/19
# train loss: 0.0298
# validation loss: 0.1152, acc: 0.3900
# Epoch 364/500
# ----------
# 10/19
# train loss: 0.0448
# validation loss: 0.1062, acc: 0.3700
# Epoch 365/500
# ----------
# 10/19
# train loss: 0.0523
# validation loss: 0.1938, acc: 0.4000
# Epoch 366/500
# ----------
# 10/19
# train loss: 0.0554
# validation loss: 0.1345, acc: 0.3733
# Epoch 367/500
# ----------
# 10/19
# train loss: 0.0419
# validation loss: 0.1537, acc: 0.3533
# Epoch 368/500
# ----------
# 10/19
# train loss: 0.0455
# validation loss: 0.1184, acc: 0.4400
# Epoch 369/500
# ----------
# 10/19
# train loss: 0.0357
# validation loss: 0.0835, acc: 0.3767
# Epoch 370/500
# ----------
# 10/19
# train loss: 0.0321
# validation loss: 0.1060, acc: 0.3767
# Epoch 371/500
# ----------
# 10/19
# train loss: 0.0465
# validation loss: 0.0987, acc: 0.3933
# Epoch 372/500
# ----------
# 10/19
# train loss: 0.0332
# validation loss: 0.0772, acc: 0.4600
# Epoch 373/500
# ----------
# 10/19
# train loss: 0.0304
# validation loss: 0.0758, acc: 0.3933
# Epoch 374/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.0791, acc: 0.4667
# Epoch 375/500
# ----------
# 10/19
# train loss: 0.0349
# validation loss: 0.0769, acc: 0.4433
# Epoch 376/500
# ----------
# 10/19
# train loss: 0.0647
# validation loss: 0.2788, acc: 0.3700
# Epoch 377/500
# ----------
# 10/19
# train loss: 0.0693
# validation loss: 0.1479, acc: 0.3867
# Epoch 378/500
# ----------
# 10/19
# train loss: 0.0439
# validation loss: 0.1255, acc: 0.4000
# Epoch 379/500
# ----------
# 10/19
# train loss: 0.0436
# validation loss: 0.1249, acc: 0.3367
# Epoch 380/500
# ----------
# 10/19
# train loss: 0.0448
# validation loss: 0.1083, acc: 0.3933
# Epoch 381/500
# ----------
# 10/19
# train loss: 0.0346
# validation loss: 0.0843, acc: 0.4133
# Epoch 382/500
# ----------
# 10/19
# train loss: 0.0368
# validation loss: 0.1141, acc: 0.3633
# Epoch 383/500
# ----------
# 10/19
# train loss: 0.0504
# validation loss: 0.1262, acc: 0.4400
# Epoch 384/500
# ----------
# 10/19
# train loss: 0.0404
# validation loss: 0.0848, acc: 0.4200
# Epoch 385/500
# ----------
# 10/19
# train loss: 0.0526
# validation loss: 0.1684, acc: 0.3900
# Epoch 386/500
# ----------
# 10/19
# train loss: 0.0422
# validation loss: 0.1396, acc: 0.3967
# Epoch 387/500
# ----------
# 10/19
# train loss: 0.0361
# validation loss: 0.0927, acc: 0.4433
# Epoch 388/500
# ----------
# 10/19
# train loss: 0.0374
# validation loss: 0.1191, acc: 0.4267
# Epoch 389/500
# ----------
# 10/19
# train loss: 0.0652
# validation loss: 0.1457, acc: 0.3867
# Epoch 390/500
# ----------
# 10/19
# train loss: 0.0381
# validation loss: 0.1066, acc: 0.4233
# Epoch 391/500
# ----------
# 10/19
# train loss: 0.0312
# validation loss: 0.0899, acc: 0.3833
# Epoch 392/500
# ----------
# 10/19
# train loss: 0.0424
# validation loss: 0.1069, acc: 0.3967
# Epoch 393/500
# ----------
# 10/19
# train loss: 0.0358
# validation loss: 0.0962, acc: 0.4000
# Epoch 394/500
# ----------
# 10/19
# train loss: 0.0392
# validation loss: 0.1194, acc: 0.3367
# Epoch 395/500
# ----------
# 10/19
# train loss: 0.0505
# validation loss: 0.0954, acc: 0.4667
# Epoch 396/500
# ----------
# 10/19
# train loss: 0.0366
# validation loss: 0.0794, acc: 0.4367
# Epoch 397/500
# ----------
# 10/19
# train loss: 0.0394
# validation loss: 0.0950, acc: 0.3867
# Epoch 398/500
# ----------
# 10/19
# train loss: 0.0299
# validation loss: 0.0835, acc: 0.3867
# Epoch 399/500
# ----------
# 10/19
# train loss: 0.0394
# validation loss: 0.1267, acc: 0.4000
# Epoch 400/500
# ----------
# 10/19
# train loss: 0.0566
# validation loss: 0.1266, acc: 0.3667
# Epoch 401/500
# ----------
# 10/19
# train loss: 0.0567
# validation loss: 0.1361, acc: 0.4200
# Epoch 402/500
# ----------
# 10/19
# train loss: 0.0450
# validation loss: 0.1447, acc: 0.2833
# Epoch 403/500
# ----------
# 10/19
# train loss: 0.0367
# validation loss: 0.1268, acc: 0.4133
# Epoch 404/500
# ----------
# 10/19
# train loss: 0.0442
# validation loss: 0.1239, acc: 0.4300
# Epoch 405/500
# ----------
# 10/19
# train loss: 0.0358
# validation loss: 0.1188, acc: 0.4100
# Epoch 406/500
# ----------
# 10/19
# train loss: 0.0482
# validation loss: 0.2408, acc: 0.3600
# Epoch 407/500
# ----------
# 10/19
# train loss: 0.0752
# validation loss: 0.1990, acc: 0.4400
# Epoch 408/500
# ----------
# 10/19
# train loss: 0.0490
# validation loss: 0.1637, acc: 0.3733
# Epoch 409/500
# ----------
# 10/19
# train loss: 0.0340
# validation loss: 0.0911, acc: 0.4367
# Epoch 410/500
# ----------
# 10/19
# train loss: 0.0255
# validation loss: 0.0718, acc: 0.4267
# Epoch 411/500
# ----------
# 10/19
# train loss: 0.0419
# validation loss: 0.1082, acc: 0.3733
# Epoch 412/500
# ----------
# 10/19
# train loss: 0.0402
# validation loss: 0.0914, acc: 0.4167
# Epoch 413/500
# ----------
# 10/19
# train loss: 0.0288
# validation loss: 0.1061, acc: 0.4100
# Epoch 414/500
# ----------
# 10/19
# train loss: 0.0298
# validation loss: 0.0700, acc: 0.4333
# Epoch 415/500
# ----------
# 10/19
# train loss: 0.0430
# validation loss: 0.2322, acc: 0.3567
# Epoch 416/500
# ----------
# 10/19
# train loss: 0.0398
# validation loss: 0.0837, acc: 0.4167
# Epoch 417/500
# ----------
# 10/19
# train loss: 0.0297
# validation loss: 0.1274, acc: 0.3933
# Epoch 418/500
# ----------
# 10/19
# train loss: 0.0609
# validation loss: 0.1117, acc: 0.4133
# Epoch 419/500
# ----------
# 10/19
# train loss: 0.0497
# validation loss: 0.1091, acc: 0.4433
# Epoch 420/500
# ----------
# 10/19
# train loss: 0.0445
# validation loss: 0.1123, acc: 0.3833
# Epoch 421/500
# ----------
# 10/19
# train loss: 0.0371
# validation loss: 0.0821, acc: 0.4367
# Epoch 422/500
# ----------
# 10/19
# train loss: 0.0299
# validation loss: 0.1095, acc: 0.3733
# Epoch 423/500
# ----------
# 10/19
# train loss: 0.0356
# validation loss: 0.1145, acc: 0.3900
# Epoch 424/500
# ----------
# 10/19
# train loss: 0.0520
# validation loss: 0.1149, acc: 0.4333
# Epoch 425/500
# ----------
# 10/19
# train loss: 0.0426
# validation loss: 0.1188, acc: 0.4100
# Epoch 426/500
# ----------
# 10/19
# train loss: 0.0427
# validation loss: 0.1082, acc: 0.3767
# Epoch 427/500
# ----------
# 10/19
# train loss: 0.0488
# validation loss: 0.2013, acc: 0.3000
# Epoch 428/500
# ----------
# 10/19
# train loss: 0.0538
# validation loss: 0.1136, acc: 0.3933
# Epoch 429/500
# ----------
# 10/19
# train loss: 0.0295
# validation loss: 0.0956, acc: 0.3500
# Epoch 430/500
# ----------
# 10/19
# train loss: 0.0326
# validation loss: 0.0665, acc: 0.4433
# Epoch 431/500
# ----------
# 10/19
# train loss: 0.0310
# validation loss: 0.0847, acc: 0.4500
# Epoch 432/500
# ----------
# 10/19
# train loss: 0.0621
# validation loss: 0.1389, acc: 0.4100
# Epoch 433/500
# ----------
# 10/19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb 셀 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> trained_classifier = train_classifier(num_epochs=500)
#
# /home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb 셀 26 in train_classifier(num_epochs, st_epoch)
#      <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     linear_classifier.eval()    # Set query encoder to evaluate mode
#      <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> # Epoch
# ---> <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> for batch, (images, labels) in enumerate(dataloaders[phase], 1):
#      <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     if batch % 10 == 0:
#      <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>         print('{}/{}'.format(batch, len(dataloaders[phase])))
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/torch/utils/data/dataloader.py:652, in _BaseDataLoaderIter.__next__(self)
#     649 if self._sampler_iter is None:
#     650     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     651     self._reset()  # type: ignore[call-arg]
# --> 652 data = self._next_data()
#     653 self._num_yielded += 1
#     654 if self._dataset_kind == _DatasetKind.Iterable and \
#     655         self._IterableDataset_len_called is not None and \
#     656         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1330, in _MultiProcessingDataLoaderIter._next_data(self)
#    1327     return self._process_data(data)
#    1329 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1330 idx, data = self._get_data()
#    1331 self._tasks_outstanding -= 1
#    1332 if self._dataset_kind == _DatasetKind.Iterable:
#    1333     # Check for _IterableDatasetStopIteration
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1296, in _MultiProcessingDataLoaderIter._get_data(self)
#    1292     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1293     # need to call `.task_done()` because we don't use `.join()`.
#    1294 else:
#    1295     while True:
# -> 1296         success, data = self._try_get_data()
#    1297         if success:
#    1298             return data
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1134, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1121 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1122     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1123     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1131     # Returns a 2-tuple:
#    1132     #   (bool: whether successfully get data, any: data if successful else None)
#    1133     try:
# -> 1134         data = self._data_queue.get(timeout=timeout)
#    1135         return (True, data)
#    1136     except Exception as e:
#    1137         # At timeout and error, we manually check whether any worker has
#    1138         # failed. Note that this is the only mechanism for Windows to detect
#    1139         # worker failures.
#
# File ~/miniconda3/envs/test/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/miniconda3/envs/test/lib/python3.10/multiprocessing/connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File ~/miniconda3/envs/test/lib/python3.10/multiprocessing/connection.py:429, in Connection._poll(self, timeout)
#     428 def _poll(self, timeout):
# --> 429     r = wait([self], timeout)
#     430     return bool(r)
#
# File ~/miniconda3/envs/test/lib/python3.10/multiprocessing/connection.py:936, in wait(object_list, timeout)
#     933     deadline = time.monotonic() + timeout
#     935 while True:
# --> 936     ready = selector.select(timeout)
#     937     if ready:
#     938         return [key.fileobj for (key, events) in ready]
#
# File ~/miniconda3/envs/test/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
trained_classifier, optimizer, qst_epoch = load(ckpt_dir=classifier_chk_path, model=linear_classifier, optim=optimizer)
print(qst_epoch)
# Out:
# 28

# %% [markdown]
# # T-SNE 시각화

# %%
from sklearn.manifold import TSNE

tsne = TSNE()

def plot_vecs_n_labels(v, labels, fname):
    fig = plt.figure(figsize = (10,10))
    plt.axis('off')
    sn.set_style('darkgrid')
    sn.scatterplot(v[:,0], v[:,1], hue=labels, legend='full', palette=sn.color_palette("bright", 4))
    plt.legend(['ADC', 'HGD', 'LGD', 'NOR'])
    plt.savefig(fname)

dataloaders['train'] = DataLoader(image_datasets['train'], 3000, True)
dataloaders['validation'] = DataLoader(image_datasets['validation'], 3000, True)
dataloaders['test'] = DataLoader(image_datasets['test'], 3000, True)

for x,y in dataloaders['test']:
    print(len(x))
    x = x.to(device)
    with torch.no_grad():
        pred = q_encoder(x)
        pred = linear_classifier(pred)
    pred_tsne = tsne.fit_transform(pred.cpu().data)
    plot_vecs_n_labels(pred_tsne, y, 'tsen.png')
    break
# Out:
# 301
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/sundongk/miniconda3/envs/test/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %% [markdown]
# ## Loss 및 Accuracy 저장

# %%
import pickle
# loss 및 acc 정보 저장
loss_dict = {}
loss_dict['train_loss'] = train_loss; loss_dict['val_loss'] = val_loss

# loss_dict 저장
with open('data_dict.pkl','wb') as f:
    pickle.dump(loss_dict,f)

# %% [markdown]
# # 시각화 및 평가

# %%
import pickle
# loss_dict 불러오기
loss_info_path = '/home/sundongk/Self-supervised_contrastive_learning/data_dict.pkl'
with open(loss_info_path,'rb') as f:
    mydict = pickle.load(f)

train_loss = mydict['train_loss']; #train_acc = mydict['train_acc']
val_loss = mydict['val_loss']; #val_acc = mydict['val_acc']

# %%
# Loss 시각화
_tloss = np.asarray([]); _vloss = np.asarray([])
for i in train_loss:
    _tloss = np.append(_tloss, i.detach().cpu().numpy())
for i in val_loss:
    _vloss = np.append(_vloss, i.detach().cpu().numpy())


plt.figure(figsize=(15, 6)) 
plt.subplot(1,2,1)
plt.ylabel('loss'); plt.xlabel('epoch')
plt.plot(_tloss, 'b', label='train loss')
plt.plot(_vloss, 'g', label='val loss')
plt.legend(loc='best')
plt.show()

# %%
# Acc 시각화
plt.figure(figsize=(15, 6)) 
plt.subplot(1,2,1)
plt.ylabel('accuracy'); plt.xlabel('epoch')
plt.plot(train_acc, 'b', label='train acc')
plt.plot(val_acc, 'g', label='val acc')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb 셀 34 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.subplot(1,2,1)
#       <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> plt.ylabel('accuracy'); plt.xlabel('epoch')
# ----> <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.plot(train_acc, 'b', label='train acc')
#       <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> plt.plot(val_acc, 'g', label='val acc')
#       <a href='vscode-notebook-cell://ssh-remote%2B161.122.53.27/home/sundongk/Self-supervised_contrastive_learning/Self-supervised_contrastive_learning.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> plt.legend(loc='best')
#
# NameError: name 'train_acc' is not defined

# %%
plt.show(); plt.close('all'); plt.clf()
model, optimizer, st_epoch = load(ckpt_dir=checkpoint_path_1, model=model, optim=optimizer)
print(st_epoch)

# %% [markdown]
# # Test 데이터셋에 대한 결과

# %%
# Inference
total = correct = 0

model.eval()
with torch.no_grad():
    running_corrects = 0
    
    for batch, item in enumerate(dataloaders['test'], 1):
        inputs = item['input'].to(device)
        labels = item['label'].to(device)

        outputs = model(inputs)

        probs = nn.Softmax(dim=1)(outputs)
        predicts = torch.argmax(outputs, dim=1)

        total += len(labels)
        correct += (predicts == labels).sum().item()
        # print(probs, predicts, labels)
        # # 불러온 이미지 시각화
        # plt.figure(figsize=(12,12))
        # input_image_example = plt.subplot(1,3,1)
        # input_image_example.set_title(f'ADC: {100*pred_probs[0][3]:.2f}, HGD: {100*pred_probs[0][2]:.2f}, LGD: {100*pred_probs[0][1]:.2f}, NOR: {100*pred_probs[0][0]:.2f}')

        # plt.imshow(to_pil_image(changeTensor(inputs)))
        # print(outputs, labels, pred_probs)
        # print(f'NOR: {100*pred_probs[0][0]:.2f}, LGD: {100*pred_probs[0][1]:.2f}, HGD: {100*pred_probs[0][2]:.2f}, ADC: {100*pred_probs[0][3]:.2f}, ')
        # plt.show()
        # plt.close('all')
        # plt.clf()
    print('Test Accuracy of the model on the {} test images: {}%'.format(total, 100 * correct / total))

# %%
print(model)

# %% [markdown]
# # Confusion matrix

# %%
# ADC: 51, HGD:50, LGD:100, NOR:100
y_pred = []
y_true = []

# Inference
model.eval()
with torch.no_grad():
    for batch, item in enumerate(dataloaders['test'], 1):
        inputs = item['input'].to(device)
        labels = item['label'].to(device)

        outputs = model(inputs)
        outputs = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        y_pred.extend(outputs) # save prediction

        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # save ground truth

class_names = ('ADC', 'HGD', 'LGD', 'NOR')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
# Create pandas dataframe
dataframe = pd.DataFrame(cf_matrix, index=class_names, columns=class_names)

sn.heatmap(dataframe, annot=True, cbar=None,cmap="YlGnBu",fmt="d")
plt.title("Confusion Matrix"), plt.tight_layout()
 
plt.ylabel("True Class"), 
plt.xlabel("Predicted Class")
plt.show()

# %%
from sklearn.metrics import classification_report
from pprint import pprint as pp

pp(classification_report(y_true, y_pred))

# %% [markdown]
# # Grad-CAM

# %%
import cv2 

class FeatureExtractor():
    """ Class for extracting activations and 
    registering gradients from targetted intermediate layers """

    def __init__(self, model, target_layers):
        self.model = model
        self.target_layers = target_layers
        self.gradients = []

    def save_gradient(self, grad):
        self.gradients.append(grad)

    def __call__(self, x):
        outputs = []
        self.gradients = []
        for name, module in self.model._modules.items():
            x = module(x)
            if name in self.target_layers:
                x.register_hook(self.save_gradient)
                outputs += [x]
        return outputs, x


class ModelOutputs():
    """ Class for making a forward pass, and getting:
    1. The network output.
    2. Activations from intermeddiate targetted layers.
    3. Gradients from intermeddiate targetted layers. """

    def __init__(self, model, feature_module, target_layers):
        self.model = model
        self.feature_module = feature_module
        self.feature_extractor = FeatureExtractor(self.feature_module, target_layers)

    def get_gradients(self):
        return self.feature_extractor.gradients

    def __call__(self, x):
        target_activations = []
        #print(x.shape)
        for name, module in self.model._modules.items():
            if module == self.feature_module:
                target_activations, x = self.feature_extractor(x)
            elif "avgpool" in name.lower():
                x = module(x)
                x = x.view(x.size(0),-1)
            else:
                x = module(x)
        
        return target_activations, x


def preprocess_image(img):
    means = [0.485, 0.456, 0.406]
    stds = [0.229, 0.224, 0.225]

    preprocessed_img = img.copy()[:, :, ::-1]
    for i in range(3):
        preprocessed_img[:, :, i] = preprocessed_img[:, :, i] - means[i]
        preprocessed_img[:, :, i] = preprocessed_img[:, :, i] / stds[i]
    preprocessed_img = \
        np.ascontiguousarray(np.transpose(preprocessed_img, (2, 0, 1)))
    preprocessed_img = torch.from_numpy(preprocessed_img)
    preprocessed_img.unsqueeze_(0)
    input = preprocessed_img.requires_grad_(True)
    return input


def show_cam_on_image(img, mask):
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    cam = heatmap + np.float32(img)
    cam = cam / np.max(cam)
    os.path.join(base_dir, "cam.jpg")
    #cv2.imwrite("cam.jpg", np.uint8(255 * cam))
    cv2.imwrite(os.path.join(base_dir, "cam.jpg"), np.uint8(255 * cam))

class GradCam:
    def __init__(self, model, feature_module, target_layer_names, use_cuda):
        self.model = model
        self.feature_module = feature_module
        self.model.eval()
        self.cuda = use_cuda
        if self.cuda:
            self.model = model.cuda()

        self.extractor = ModelOutputs(self.model, self.feature_module, target_layer_names)

    def forward(self, input):
        return self.model(input)

    def __call__(self, input, index=None):
        if self.cuda:
            features, output = self.extractor(input.cuda())#[1, 2048, 7, 7], [1, 1000]
        else:
            features, output = self.extractor(input)


        if index == None:
            index = np.argmax(output.cpu().data.numpy())
        #print(index)

        one_hot = np.zeros((1, output.size()[-1]), dtype=np.float32)#1,1000
        one_hot[0][index] = 1
        one_hot = torch.from_numpy(one_hot).requires_grad_(True)
        if self.cuda:
            one_hot = torch.sum(one_hot.cuda() * output)
            print(one_hot)
        else:
            one_hot = torch.sum(one_hot * output)

        self.feature_module.zero_grad()
        self.model.zero_grad()
        one_hot.backward(retain_graph=True)

        grads_val = self.extractor.get_gradients()[-1].cpu().data.numpy()#1, 2048, 7, 7
        target = features[-1]#1,2048,7,7
        target = target.cpu().data.numpy()[0, :]#2048, 7, 7

        weights = np.mean(grads_val, axis=(2, 3))[0, :]#2048
        cam = np.zeros(target.shape[1:], dtype=np.float32)

        for i, w in enumerate(weights):#w:weight,target:feature
            cam += w * target[i, :, :]

        cam = np.maximum(cam, 0)#7,7
        cam = cv2.resize(cam, input.shape[2:])#224,224
        cam = cam - np.min(cam)
        cam = cam / np.max(cam)
        return cam

# %%
# ADC_img_path = '/disk1/colonoscopy_dataset/cropped/ADC/'
# ADC_file_list = os.listdir(ADC_img_path) # ADC 전체 파일 목록
# ADC_data_list = sorted([x for x in ADC_file_list if 'IMG' in x])        # ADC data 파일 목록

grad_cam = GradCam(model=model, feature_module=model.layer4, target_layer_names=["2"], use_cuda=True)
# Inference
total = correct = 0
model.eval()

#with torch.no_grad():
running_corrects = 0
for item in ADC_data_list:
    path = os.path.join(ADC_img_path, item)
    img = cv2.imread(path, 1)
    img = np.float32(cv2.resize(img, (256, 256))) / 255
    input = preprocess_image(img)
    
    target_index = None
    mask = grad_cam(input, target_index)

    cam = show_cam_on_image(img, mask)
